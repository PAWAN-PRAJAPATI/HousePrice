# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("train.csv")
test = pd.read_csv("test.csv")
df.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities    ...     PoolArea PoolQC Fence MiscFeature MiscVal  \
# 0         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 1         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 2         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 3         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 4         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
#
#   MoSold YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
corrmat = df.corr()
cols = corrmat.nlargest(37,'SalePrice')['SalePrice'].index
zoomcorr = np.corrcoef(df[cols].values.T)

# %%
X = df[cols]

# %%
y = X['SalePrice']
X = X.drop(['SalePrice'], axis=1)

# %%
X.head()
# Out:
#    OverallQual  GrLivArea  GarageCars  GarageArea  TotalBsmtSF  1stFlrSF  \
# 0            7       1710           2         548          856       856
# 1            6       1262           2         460         1262      1262
# 2            7       1786           2         608          920       920
# 3            7       1717           3         642          756       961
# 4            8       2198           3         836         1145      1145
#
#    FullBath  TotRmsAbvGrd  YearBuilt  YearRemodAdd      ...        3SsnPorch  \
# 0         2             8       2003          2003      ...                0
# 1         2             6       1976          1976      ...                0
# 2         2             6       2001          2002      ...                0
# 3         1             7       1915          1970      ...                0
# 4         2             9       2000          2000      ...                0
#
# ...

# %%
from sklearn.preprocessing import Imputer
from sklearn.model_selection import train_test_split

my_imputer = Imputer()
X_ = my_imputer.fit_transform(X)

# %%
X = pd.DataFrame(X)
train_X, test_X, train_y, test_y = train_test_split(X.as_matrix(), y.as_matrix(), test_size=0.20)

# %%
from xgboost import XGBRegressor
from sklearn.cross_validation import cross_val_score


my_model = XGBRegressor(n_estimators=1000)
scores = cross_val_score(estimator=my_model,X=train_X,y=train_y,cv=15,n_jobs=-1)
print(scores.mean())
print(scores.std())
# Out:
# 0.818106863477
# 0.24902705681

# %%
my_model.fit(train_X,train_y)
my_model.score(test_X,test_y)
# Out:
# 0.89242893691087555

# %%
# Out:
# Index(['SalePrice', 'OverallQual', 'GrLivArea', 'GarageCars', 'GarageArea',
#        'TotalBsmtSF', '1stFlrSF', 'FullBath', 'TotRmsAbvGrd', 'YearBuilt',
#        'YearRemodAdd', 'GarageYrBlt', 'MasVnrArea', 'Fireplaces', 'BsmtFinSF1',
#        'LotFrontage', 'WoodDeckSF', '2ndFlrSF', 'OpenPorchSF', 'HalfBath',
#        'LotArea', 'BsmtFullBath', 'BsmtUnfSF', 'BedroomAbvGr', 'ScreenPorch',
#        'PoolArea', 'MoSold', '3SsnPorch', 'BsmtFinSF2', 'BsmtHalfBath',
#        'MiscVal', 'Id', 'LowQualFinSF', 'YrSold', 'OverallCond', 'MSSubClass',
#        'EnclosedPorch'],
#       dtype='object')
